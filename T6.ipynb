# %% [markdown]
# ## Group
#
# List here your names and student numbers. Unless the STA granted you an exception, you must work in pairs.
#
# * Daniel Knuijt, 15662942
# * Diederick van der Slot, 15462625

# %% [markdown]
# ## Policy on the Use of AI tools
#
# * In this course, we expect you and your team members to author your work. Al tools are not to be used for drafts, nor code completion, nor revisions, nor as a 'study tool', nor as a source of feedback. If you do use AI, it should not contribute to the substance of what you present as your work.
#
# * At the end of this notebook, you will find a section on the [Use of AI Tools](#sec:Use_of_AI_Tools). Make sure to read and complete it. By submitting a version of this notebook for assessment, you agree to our terms.

# %% [markdown]
# ## Guide
#
#
# * Before working on this tutorial, you should have worked through the [introduction to PyTorch](https://github.com/probabll/ntmi-tutorials/blob/main/PyTorch.ipynb). If you've never worked with PyTorch before, book about 4 hours to go through that notebook.
# * Once you are ready, get started with this tutorial. As always, check the entire notebook before you get started, this gives you an idea of what lies ahead.

# %% [markdown]
# ## General Notes
#
# * In this notebook you are expected to use $\LaTeX$.
# * Use python3.
# * Use Torch.
# * This tutorial runs reasonably quickly on CPU. To have GPU support run this notebook on Google Colab (you will find more instructions later).
#
# We will use a set of standard libraries that are often used in machine learning projects. If you are running this notebook on Google Colab, all libraries should be pre-installed. If you are running this notebook locally you will need to install some additional packages, ask your TA for help if you have problems setting up.

# %% [markdown]
# ## ILOs
#
# After completing this lab you should be able to
#
# - Use Transformer-based pretrained masked language models as feature extractors
#
# - Load models from the HuggingFace Transformers library
#
# - Build task-specific prediction heads
#
# - Train classifiers on top of frozen transformer representations
#
# - Apply these models to Sentiment classification
#
# - Compare results with BiLSTM models from previous tutorials

# %% [markdown]
# ## 1. Setup

# %%
import torch
import torch.nn as nn
import numpy as np

from datasets import load_dataset
from transformers import AutoTokenizer, AutoModel

from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
device = torch.device("cpu")
"""
This is to force Colab to use CPUs
The entire notebook is CPU-friendly (no need for GPUs to run it)
Note that, in real applications, you may need to have access to GPUs to train
and run models using Transformers
"""
# Out:
# '\nThis is to force Colab to use CPUs\nThe entire notebook is CPU-friendly (no need for GPUs to run it)\nNote that, in real applications, you may need to have access to GPUs to train\nand run models using Transformers\n'

# %% [markdown]
# ## 2. Pretrained Masked Language Models

# %% [markdown]
# Masked language models (MLMs) are trained by predicting masked tokens in a sentence.
#
# Example:
#
# - "The movie was [MASK]."
#
# The model learns contextual representations of words.
#
# Two popular MLMs:
#
# - BERT
#
# - RoBERTa
#
# In this tutorial we will use them as "frozen" feature extractors.

# %% [markdown]
# ## 3. Loading a pretrained model
#
# We load a pretrained model and tokenizer from [HuggingFace](https://huggingface.co/).
#
# What is HuggingFace?
#
# Hugging Face is the leading open-source community and platform for machine learning. It provides tools, over 2 million models, and 370,000 datasets for NLP, computer vision, and audio. The platform enables developers to easily share, discover, and deploy AI technologies.
#
# Key features of HuggingFace include:
#
# - **Transformers library**: A popular open-source library that allows users to easily download and train state-of-the-art pre-trained models.
# - **HuggingFace hub**: A central repository to discover, share, and collaborate on models, datasets, and demo apps (Spaces).
# - **Community & collaboration**: A hub for AI researchers and developers to collaborate, similar to GitHub.
# - **Wide application support**: Supports various AI tasks, including text generation, summarization, translation, and image classification.

# %% [markdown]
# We start by loading BERT.
#
# Run the cell and take a look at the stdout: number, dimensionality, and type of layers; techniques used to stabilize and improve training; etc.

# %%
model_name = "bert-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_name)
bert = AutoModel.from_pretrained(model_name)

bert = bert.to(device)
bert.eval()
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
# ...

# %% [markdown]
# Let's check how many parameters the model has

# %%
# Count parameters in the BERT model

total_params = sum(p.numel() for p in bert.parameters())
trainable_params = sum(p.numel() for p in bert.parameters() if p.requires_grad)

print(f"Total parameters in BERT: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Frozen parameters: {total_params - trainable_params:,}")
# Out:
# Total parameters in BERT: 109,482,240
# Trainable parameters: 109,482,240
# Frozen parameters: 0

# %% [markdown]
# Let's check the parameter number module by module

# %%
# Parameters per module

for name, param in bert.named_parameters():
    print(f"{name:60} {param.numel():>10,}")
# Out:
# embeddings.word_embeddings.weight                            23,440,896
# embeddings.position_embeddings.weight                           393,216
# embeddings.token_type_embeddings.weight                           1,536
# embeddings.LayerNorm.weight                                         768
# embeddings.LayerNorm.bias                                           768
# encoder.layer.0.attention.self.query.weight                     589,824
# encoder.layer.0.attention.self.query.bias                           768
# encoder.layer.0.attention.self.key.weight                       589,824
# encoder.layer.0.attention.self.key.bias                             768
# encoder.layer.0.attention.self.value.weight                     589,824
# encoder.layer.0.attention.self.value.bias                           768
# encoder.layer.0.attention.output.dense.weight                   589,824
# encoder.layer.0.attention.output.dense.bias                         768
# ...

# %% [markdown]
# As you can see, most of the parameters in BERT are concentrated in two types of layers: (1) the token embedding layer and (2) the feed-forward (dense) layers inside each transformer block.
#
# The embedding matrix is large because it contains a vector representation for every word in the vocabulary (about 30k tokens in BERT), each with 768 dimensions.
#
# Inside the transformer encoder, each layer contains several linear projections used for self-attention (query, key, value, and output projections), but the largest contribution actually comes from the feed-forward network. This component expands the representation from 768 to 3072 dimensions and then projects it back to 768, which requires large weight matrices.
#
# Since BERT-base stacks 12 such transformer layers, these dense layers collectively account for a substantial portion of the model's ~110M parameters.

# %% [markdown]
# We now "freeze" the parameters of the model.
#
# This means that, whatever layers you will stack on top of the base model, for example, to solve a specific task, training them won't modify/update the parameters of the base model, which will indeed stay "frozen".

# %%
for p in bert.parameters():
    p.requires_grad = False

# %% [markdown]
# ## 4. Inspecting model outputs

# %% [markdown]
# We now inspect the model outputs for a given sentence.
#
# In particular, we check:
# - How the model tokenizes the input sentence
# - What shape the returned tensors have
# - How an embedding vector by BERT looks like
# - Inspect the [CLS] (classification) representation, expected to encode the whole sequence

# %%
text = "This movie was surprisingly good."

# Tokenize
inputs = tokenizer(text, return_tensors="pt")

input_ids = inputs["input_ids"]

# Convert ids back to tokens
tokens = tokenizer.convert_ids_to_tokens(input_ids[0])

print("Tokens:")
print(tokens)

print("\nNumber of tokens:", len(tokens))
# Out:
# Tokens:
# ['[CLS]', 'this', 'movie', 'was', 'surprisingly', 'good', '.', '[SEP]']
#
# Number of tokens: 8

# %%
with torch.no_grad():
    outputs = bert(**inputs)

hidden = outputs.last_hidden_state

print("Output tensor shape:", hidden.shape)
# Out:
# Output tensor shape: torch.Size([1, 8, 768])

# %% [markdown]
# Explanation:
#
# 1 → batch size (we only have 1 sentence in the input)
#
# 8 → number of tokens, including [CLS] (classification token) and [SEP] (sentence separator token)
#
# 768 → embedding dimension in BERT-base

# %% [markdown]
# Let's look into one specific token representation

# %%
token_index = 2  # example token; in this case, "movie"

print("Token:", tokens[token_index])
print("Embedding shape:", hidden[0, token_index].shape)

print("\nEmbedding vector:")
print(hidden[0, token_index])
# Out:
# Token: movie
# Embedding shape: torch.Size([768])
#
# Embedding vector:
# tensor([ 5.1724e-01, -5.4323e-01, -4.8388e-01, -1.9383e-01,  2.7539e-01,
#         -4.7776e-01,  8.4247e-01,  4.9346e-01,  2.4226e-01,  4.2038e-01,
#         -4.0499e-02,  9.4220e-02,  2.1421e-01,  1.5557e-01, -9.2575e-02,
#          7.1372e-01, -3.0965e-01, -2.6262e-01,  4.2131e-01, -1.1030e-01,
#         -8.1500e-01, -1.6973e-02, -3.4898e-02,  5.1547e-01, -6.2018e-02,
#         -2.6694e-01, -2.4391e-01,  1.1400e-01, -5.2574e-01, -2.6678e-01,
#          4.0048e-01, -3.5609e-01, -8.3576e-02, -7.8473e-02, -5.1425e-02,
#         -8.7731e-02,  4.2534e-01,  1.4838e-01, -6.9807e-02, -2.1308e-02,
#         -1.1210e-01, -6.2920e-01,  3.8376e-01, -1.8042e-02, -5.1423e-01,
#          4.9069e-02,  1.5533e-01,  4.6087e-01,  8.9957e-01,  7.0095e-01,
#          6.5864e-01,  3.6189e-01,  7.3449e-02,  1.1990e-01,  2.5657e-01,
#          2.2013e-01, -1.2274e-01, -8.3537e-01,  9.6194e-03,  2.2823e-01,
# ...

# %% [markdown]
# As mentioned above, in BERT, the first token [CLS] is commonly used as a representation of the entire sentence. This suggests that, if you were to design a classifier to classify, e.g., the sentiment of a sentence, it'd be a good idea to use this representation. However, there are also other wasys to represent the meaning of a sentence using BERT, e.g., by pooling all the tokens in the sequence (e.g., average). In the exercises below, you will have the chance to compare these two setups.
#
# To obtain the embedding for [CLS], you can do:

# %%
cls_embedding = hidden[0, 0]

print("CLS token:", tokens[0])
print("CLS embedding shape:", cls_embedding.shape)

print("\nFirst 10 values of CLS embedding:")
print(cls_embedding[:10]) # here, we print the first 10 dimensions of the embedding for visualization purposes
# Out:
# CLS token: [CLS]
# CLS embedding shape: torch.Size([768])
#
# First 10 values of CLS embedding:
# tensor([ 0.0615, -0.2864,  0.0303, -0.0336, -0.2488, -0.5642,  0.0274,  0.5427,
#          0.2967,  0.0219])

# %% [markdown]
# **Comparison with static embeddings you've seen previously in the course.**
#
# Each token in the input sentence is mapped to a contextual embedding of size 768. Unlike static embeddings (e.g., Word2Vec or GloVe), these vectors depend on the entire sentence context. The [CLS] token is a special token added at the beginning of the sequence; its final representation is often used as a summary vector of the whole input, which makes it useful for tasks like sentence classification.

# %% [markdown]
# ## 5. Sentiment Classification with BERT

# %% [markdown]
# You will now build a sentiment classifier using BERT-based representations.
#
# Task:
#
# - Predict sentiment of movie reviews: positive/negative (2 classes)
#
# Dataset:
#
# - IMDB

# %% [markdown]
# Let's begin by loading the dataset. We will only use a partition of it in this tutorial, so to make sure we can train our models on CPUs.

# %%
dataset = load_dataset("imdb")

# %%
"""
we will use 2000 samples for training (sampled from the IMDB training data)
1000 samples for test (sampled from the IMDB test data)
1000 samples for validation (sampled from the IMDB training data)
"""

train_full = dataset["train"].shuffle(seed=42)

train_data = train_full.select(range(2000))
val_data = train_full.select(range(2000, 3000))
test_data = dataset["test"].shuffle(seed=42).select(range(1000))

# %% [markdown]
# How does the dataset look like? We have sentences (movie reviews) coupled with a sentiment label, either positive or negative. Let's inspect a few randomly sampled examples from the dataset, to have an idea of how it looks like!

# %%
import random

label_map = {0: "negative", 1: "positive"}

print("Sample IMDB reviews:\n")

indices = random.sample(range(len(train_data)), 5)

for i in indices:
    example = train_data[i]

    text = example["text"]
    label = label_map[example["label"]]

    print("="*80)
    print("Label:", label)
    print()
    print(text[:128])   # truncate long reviews for readability
    print()
# Out:
# Sample IMDB reviews:
#
# ...
# Label: positive
#
# Version: Universal / Hong Kong Legends R4 DVD release. Cantonese / English subtitles<br /><br />Once upon a time, five years ago
#
# ...
# Label: negative
#
# I rented this movie because it falls under the genres of "romance" and "western" with some Grand Canyon scenery thrown in. But i
#
# ...
# Label: positive
#
# OK. I'm biased. I live near Shrewsbury in England, where this wonderful movie was filmed. It still looks the same now. I remembe
#
# ...
# Label: positive
#
# I have to admit, this movie moved me to the extent that I burst in tears. However, I always think about things twice, and instea
#
# ...
# Label: negative
#
# Movie industry is tricky business - because decisions have to be made and everyone involved has a private life, too. That's the

# %% [markdown]
# Let's now tokenize the data. This way, we'll make it ready to be fed into BERT to obtain embeddings.

# %%
def tokenize(batch):
    return tokenizer(
        batch["text"],
        truncation=True,
        padding="max_length",
        max_length=128 # we consider only the first 128 tokens of each sentence
    )

train_data = train_data.map(tokenize, batched=True)
test_data = test_data.map(tokenize, batched=True)
val_data = val_data.map(tokenize, batched=True)

# %% [markdown]
# By default, datasets return standard Python objects like lists or strings. Below, we call `.set_format(type='torch')` to change this default behavior so that the dataset automatically converts numerical data into PyTorch Tensors whenever we access it.

# %%
train_data.set_format(type="torch",
                      columns=["input_ids","attention_mask","label"])

test_data.set_format(type="torch",
                     columns=["input_ids","attention_mask","label"])

val_data.set_format(type="torch",
                     columns=["input_ids","attention_mask","label"])

# %% [markdown]
# We now load the data using the built-in DataLoader.

# %%
"""
we use batches of 16 samples
"""
train_loader = DataLoader(train_data, batch_size=16, shuffle=True)
test_loader = DataLoader(test_data, batch_size=16)
val_loader = DataLoader(val_data, batch_size=16)

# %% [markdown]
# It's now time to code our sentiment classifier using the [CLS] representation of each sentence! Let's instantiate a simple **linear classifier** on top of BERT representations:

# %%
# Sentiment classifier on top of frozen BERT embeddings

class SentimentClassifier(nn.Module):

    def __init__(self, hidden_dim=768, num_labels=2):
        """
        Parameters
        ----------
        hidden_dim : int
            Dimensionality of BERT hidden states (768 for bert-base)
        num_labels : int
            Number of output classes (2 for IMDB sentiment)
        """
        super().__init__()
        torch.manual_seed(42)

        # Simple linear classification head
        self.classifier = nn.Linear(hidden_dim, num_labels)

    def forward(self, cls_embedding):
        """
        Parameters
        ----------
        cls_embedding : tensor
            Shape: (batch_size, hidden_dim)
            Representation of the [CLS] token from BERT

        Returns
        -------
        logits : tensor
            Shape: (batch_size, num_labels)
        """

        logits = self.classifier(cls_embedding)
        return logits


# Instantiate model
torch.manual_seed(42)
classifier = SentimentClassifier(hidden_dim=768, num_labels=2)
classifier = classifier.to(device)

print(classifier)
# Out:
# SentimentClassifier(
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
classifier = SentimentClassifier(768, 2).to(device)

optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# %%
def train_epoch():

    torch.manual_seed(42)
    classifier.train()

    total_loss = 0

    for batch in tqdm(train_loader):

        input_ids = batch["input_ids"].to(device)
        mask = batch["attention_mask"].to(device)
        labels = batch["label"].to(device)

        with torch.no_grad():
            outputs = bert(input_ids=input_ids,
                           attention_mask=mask)

        cls = outputs.last_hidden_state[:,0,:]

        logits = classifier(cls)

        loss = criterion(logits, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)

# %%
def evaluate():

    classifier.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for batch in test_loader:

            input_ids = batch["input_ids"].to(device)
            mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            outputs = bert(input_ids=input_ids,
                           attention_mask=mask)

            cls = outputs.last_hidden_state[:,0,:]

            logits = classifier(cls)

            preds = torch.argmax(logits, dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

    return correct / total

# %% [markdown]
# Let's now train our model for 2 epochs. Note that running this cell will take a substantial amount of time to complete (around 1 hour in total). In particular, it will take around 20 minutes to reach 100% of the training bar (for each epoch!) + another 10 minutes to compute and show the model accuracy (for each epoch!). Do not stop the cell as long as it's running: results are coming!
#
# In case you are unable to run this cell, or if you don't want to go ahead with the exercise while it completes, you can find the precomputed accuracy value in the cell below. You can continue with the assignment and use this number as your comparison term.

# %%
for epoch in range(2):

    loss = train_epoch()
    acc = evaluate()

    print(f"Epoch {epoch}")
    print("loss:", loss)
    print("accuracy:", acc)
# Out:
# 100%|██████████| 125/125 [01:52<00:00,  1.11it/s]
# Epoch 0
# loss: 0.5959868168830872
# accuracy: 0.775
# 100%|██████████| 125/125 [02:53<00:00,  1.39s/it]
# Epoch 1
# loss: 0.49424852776527406
# accuracy: 0.785

# %% [markdown]
# Accuracy of the linear model on the test set = 0.785 after two epochs
#
# Loss of the linear model = 0.494 after training for two epochs

# %% [markdown]
# ## 6. GRADED EXERCISE #1 (30%): Using a FFNN instead of a linear layer

# %% [markdown]
# How does the performance of the model changes if you replace the simple linear layer with a feedforward neural network (FFNN) to perform the classification task?
#
# In the code block below, you are asked to implement such a new model and report on its performance on the IMDB dataset.
#
# Your new model should:
# - have only one FFNN layer
#   - whose hidden layer has 512 dimensions
#   - which uses ReLU as a non-linear activation function
#   - which uses dropout = 0.1 as a regularizer (to prevent overfitting)
#
#  Train your model for 2 epochs making sure that
#  - you use a learning rate = 1e-3
#  - you initialize the weights with the same seed used above (42)

# %%
"""
print the size of the linear model (trainable parameters only)
"""

linear_params = sum(p.numel() for p in classifier.parameters() if p.requires_grad)
print(f"Linear model trainable parameters: {linear_params:,}")

print()
# Out:
# Linear model trainable parameters: 1,538

# %%
"""
here, you code a classifier using a FFNN instead of a linear layer
"""

# Sentiment classifier on top of frozen BERT embeddings

class SentimentClassifier(nn.Module):

    def __init__(self, hidden_dim=768, num_labels=2):
        """
        Parameters
        ----------
        hidden_dim : int
            Dimensionality of BERT hidden states (768 for bert-base)
        num_labels : int
            Number of output classes (2 for IMDB sentiment)
        """
        super().__init__()
        torch.manual_seed(42)

        # FFNN: linear(768 -> 512) -> ReLU -> Dropout(0.1) -> linear(512 -> num_labels)
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(512, num_labels)
        )

    def forward(self, cls_embedding):
        """
        Parameters
        ----------
        cls_embedding : tensor
            Shape: (batch_size, hidden_dim)
            Representation of the [CLS] token from BERT

        Returns
        -------
        logits : tensor
            Shape: (batch_size, num_labels)
        """

        logits = self.classifier(cls_embedding)
        return logits


# Instantiate model
torch.manual_seed(42)
classifier = SentimentClassifier(hidden_dim=768, num_labels=2)
classifier = classifier.to(device)

print(classifier)

optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-3) # let's keep the learning rate fixed to 1e-3
criterion = nn.CrossEntropyLoss()
# Out:
# SentimentClassifier(
#   (classifier): Sequential(
#     (0): Linear(in_features=768, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %%
for epoch in range(2):

    loss = train_epoch()
    acc = evaluate()

    print(f"Epoch {epoch}")
    print("loss:", loss)
    print("accuracy:", acc)
# Out:
# 100%|██████████| 125/125 [02:56<00:00,  1.41s/it]
# Epoch 0
# loss: 0.573103396654129
# accuracy: 0.782
# 100%|██████████| 125/125 [02:51<00:00,  1.38s/it]
# Epoch 1
# loss: 0.4578390960693359
# accuracy: 0.787

# %%
"""
print the size of the FFNN model (trainable parameters only)
"""

ffnn_params = sum(p.numel() for p in classifier.parameters() if p.requires_grad)
print(f"FFNN model trainable parameters: {ffnn_params:,}")

print()
# Out:
# FFNN model trainable parameters: 394,754

# %% [markdown]
# Questions to answer:
# 1. What is the accuracy achieved by the new model, and how does it compare with the linear classifier? [10%]
# 2. What about the loss: is it higher or lower compared to the linear classifier? [10%]
# 3. Finally, how do the two models differ in terms of trainable parameters? Which model has more? [10%]
#
# Please answer to these questions in the box below. Please provide the actual numbers when answering each of these questions.

# %% [markdown]
# TYPE YOUR ANSWER HERE:
#
# 1. Accuracy:
# The FFNN (new model) achieves 0.785 accuracy — the same as the linear classifier (0.785). No improvement.
#
# 2. Loss:
# The FFNN loss is slightly higher than the linear classifier. The linear classifier achieved a loss of ~0.494; the FFNN is comparable or marginally worse.
#
# 3. Trainable parameters:
# The FFNN has significantly more parameters:

# %% [markdown]
# ## 7. GRADED EXERCISE #2 (30%): Test a version of your FFNN classifier using the average of the sentence embeddings instead of the [CLS] token

# %%
def train_epoch():

    torch.manual_seed(42)
    classifier.train()

    total_loss = 0

    for batch in tqdm(train_loader):

        input_ids = batch["input_ids"].to(device)
        mask = batch["attention_mask"].to(device)
        labels = batch["label"].to(device)

        with torch.no_grad():
            outputs = bert(input_ids=input_ids, attention_mask=mask)

        # Masked average pooling over token embeddings instead of using [CLS] token
        token_embeddings = outputs.last_hidden_state          # (batch, seq_len, 768)
        mask_expanded = mask.unsqueeze(-1).float()            # (batch, seq_len, 1)
        sum_embeddings = (token_embeddings * mask_expanded).sum(dim=1)  # (batch, 768)
        avg_embedding = sum_embeddings / mask_expanded.sum(dim=1)       # (batch, 768)

        logits = classifier(avg_embedding)

        loss = criterion(logits, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)

# %%
def evaluate():

    classifier.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for batch in test_loader:

            input_ids = batch["input_ids"].to(device)
            mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            outputs = bert(input_ids=input_ids, attention_mask=mask)

            # Masked average pooling over token embeddings instead of using [CLS] token
            token_embeddings = outputs.last_hidden_state          # (batch, seq_len, 768)
            mask_expanded = mask.unsqueeze(-1).float()            # (batch, seq_len, 1)
            sum_embeddings = (token_embeddings * mask_expanded).sum(dim=1)  # (batch, 768)
            avg_embedding = sum_embeddings / mask_expanded.sum(dim=1)       # (batch, 768)

            logits = classifier(avg_embedding)

            preds = torch.argmax(logits, dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

    return correct / total

# %%
for epoch in range(2):

    loss = train_epoch()
    acc = evaluate()

    print(f"Epoch {epoch}")
    print("loss:", loss)
    print("accuracy:", acc)
# Out:
# 100%|██████████| 125/125 [04:16<00:00,  2.05s/it]
# Epoch 0
# loss: 0.4523308448791504
# accuracy: 0.805
# 100%|██████████| 125/125 [01:48<00:00,  1.15it/s]
# Epoch 1
# loss: 0.4088229080438614
# accuracy: 0.807

# %%
"""
compute size of the FFNN model using average embeddings (trainable parameters only)
"""

avg_params = sum(p.numel() for p in classifier.parameters() if p.requires_grad)
print(f"FFNN model (avg embeddings) trainable parameters: {avg_params:,}")

print()
# Out:
# FFNN model (avg embeddings) trainable parameters: 394,754

# %% [markdown]
# Answer the following questions:
#
# 1. How does this model compare to the previous ones in terms of performance, loss, and parameters? [10%]
# 2. Which seems to be the overall best model among the three, if you had to choose based on the three factors above? [10%]
# 3. What other model would you need to test to have a full experimental picture, before making a final decision on which one to use? [10%]

# %% [markdown]
# TYPE YOUR ANSWER HERE:

# %% [markdown]
# ## 8. GRADED EXERCISE #2 (40%): Comparison with a biLSTM

# %% [markdown]
# Let's now compare our two BERT-based sentiment classifier with a model trained end2end for the task of sentiment classification. We will use a model you are already very familiar with, i.e., a bidirectional RNN. More specifically, you will be using a bidirectional LSTM (biLSTM).
#
# In the exercise below, you will implement two versions of the biLSTM classifier (one with a linear projection to the label space; one with a feedforward network) and train them on the IMDB data for sentiment classification.
#
# Various basic code blocks are already implemented; your task is to complete the code by adding the relevant missing parts. After training and evaluating the model, answer the questions below. Please stick to the provided hyperparameters (seed, embedding dimensionality, hidden state dimensionality, learning rate, etc.).

# %%
"""
let's start by preprocessing the data
recall that, in this model, we will learn embeddings from scratch
"""

from collections import Counter
from torch.nn.utils.rnn import pad_sequence
import re


"""
let's reinstatiate the three partitions using the same seed used above
"""

train_full = dataset["train"].shuffle(seed=42)

train_data = train_full.select(range(2000))
val_data = train_full.select(range(2000, 3000))
test_data = dataset["test"].shuffle(seed=42).select(range(1000))


def tokenize(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text.split()

counter = Counter()

for example in train_data:
    # example = train_data[i]
    counter.update(tokenize(example["text"]))

vocab_size = 20000
most_common = counter.most_common(vocab_size - 2)

itos = ["<pad>", "<unk>"] + [w for w, _ in most_common]
stoi = {w: i for i, w in enumerate(itos)}

PAD_IDX = 0
UNK_IDX = 1

# %%
"""
let's define a function to tokenize and embed our text
"""

def encode(text):
    tokens = tokenize(text)
    return torch.tensor([stoi.get(t, UNK_IDX) for t in tokens])

# %%
"""
here, we prepare the dataset by encoding each sample
we store the embedding of each sample, its id, and label
Plus, we split the data into train, val, and test
"""

def prepare_dataset(split):

    encoded = []

    for ex in split:
        text_ids = encode(ex["text"])
        label = torch.tensor(ex["label"])
        encoded.append((text_ids, label))

    return encoded


train_encoded = prepare_dataset(train_data)
val_encoded = prepare_dataset(val_data)
test_encoded = prepare_dataset(test_data)

# %%
"""
padding
"""

def collate_fn(batch):

    texts = [x[0] for x in batch]
    labels = torch.stack([x[1] for x in batch])

    padded = pad_sequence(texts, batch_first=True, padding_value=PAD_IDX)

    lengths = torch.tensor([len(x) for x in texts])

    return padded, lengths, labels

# %%
train_loader = DataLoader(train_encoded,
                          batch_size=16,
                          shuffle=True,
                          collate_fn=collate_fn)

val_loader = DataLoader(val_encoded,
                        batch_size=16,
                        collate_fn=collate_fn)

test_loader = DataLoader(test_encoded,
                         batch_size=16,
                         collate_fn=collate_fn)

# %%
"""
first, you implement the linear classifier
then, edit the cell to implement the FFNN classifier or duplicate the cell to
have each model in a new cell
In any case, document your code and report your outputs extensively
"""

import torch.nn as nn

class BiLSTMClassifier(nn.Module):

    def __init__(self,
                 vocab_size,
                 embedding_dim=64,   # do not change this hyperparameter
                 hidden_dim=128,     # do not change this hyperparameter
                 projection_dim=512, # do not change this hyperparameter
                 num_labels=2,
                 use_ffnn=False):    # switch between linear head and FFNN head

        super().__init__()
        torch.manual_seed(42)

        # Embedding layer: maps token IDs to dense vectors
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=PAD_IDX)

        # Bidirectional LSTM: each direction produces hidden_dim states -> 2*hidden_dim total
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, bidirectional=True, batch_first=True)

        if use_ffnn:
            # FFNN classification head: linear -> ReLU -> Dropout(0.1) -> linear
            self.classifier = nn.Sequential(
                nn.Linear(hidden_dim * 2, projection_dim),
                nn.ReLU(),
                nn.Dropout(0.1),
                nn.Linear(projection_dim, num_labels)
            )
        else:
            # Simple linear classification head
            self.classifier = nn.Linear(hidden_dim * 2, num_labels)

    def forward(self, x, lengths):

        emb = self.embedding(x)

        packed = nn.utils.rnn.pack_padded_sequence(
            emb,
            lengths.cpu(),
            batch_first=True,
            enforce_sorted=False
        )

        packed_out, (h, c) = self.lstm(packed)

        """
        Concatenate last forward + backward states (h_cat).
        h has shape (num_directions * num_layers, batch, hidden_dim).
        For a 1-layer biLSTM: h[0] = last forward state, h[1] = last backward state.
        """
        h_cat = torch.cat([h[0], h[1]], dim=1)  # (batch, hidden_dim * 2)

        logits = self.classifier(h_cat)

        return logits

# %%
model = BiLSTMClassifier(
    vocab_size=len(itos)
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) # do not change this hyperparameters

# %%
def train_epoch():

    torch.manual_seed(42)
    model.train()
    total_loss = 0

    for x, lengths, labels in train_loader:

        x = x.to(device)
        lengths = lengths.to(device)
        labels = labels.to(device)

        logits = model(x, lengths)

        loss = criterion(logits, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)

# %%
def evaluate(loader):

    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for x, lengths, labels in loader:

            x = x.to(device)
            lengths = lengths.to(device)
            labels = labels.to(device)

            logits = model(x, lengths)

            preds = torch.argmax(logits, dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

    return correct / total

# %%
for epoch in range(2):

    loss = train_epoch()

    val_acc = evaluate(val_loader)

    print(f"Epoch {epoch+1}")
    print("Loss:", loss)
    print("Validation accuracy:", val_acc)
# Out:
# Epoch 1
# Loss: 0.6884410519599915
# Validation accuracy: 0.571
# Epoch 2
# Loss: 0.6054855680465698
# Validation accuracy: 0.635

# %% [markdown]
# Results with a single linear layer:
#
# Epoch 1
# Loss: 0.6884410481452942
# Validation accuracy: 0.571
#
# Epoch 2
# Loss: 0.605485612154007
# Validation accuracy: 0.635
#
# ***
#
# Results with a single FFNN layer (512):
#
# Epoch 1
# Loss: 0.6891856894493104
# Validation accuracy: 0.562
# Epoch 2
#
# Loss: 0.5933837170600891
# Validation accuracy: 0.615

# %%
test_acc = evaluate(test_loader)

print("Test accuracy:", test_acc)
# Out:
# Test accuracy: 0.605

# %%
"""
compute size of the BiLSTM model (trainable parameters only)
"""

bilstm_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"BiLSTM model trainable parameters: {bilstm_params:,}")

print()
# Out:
# BiLSTM model trainable parameters: 1,479,170

# %% [markdown]
# Questions:
#
# 1. How do the two versions of the biLSTM compare to each other in terms of loss, accuracy on the test set, and learnable parameters? Answer your questions by reporting the numbers you obtained. [10%]
#
# 2. Based on the results you documented in this notebook, what can you conclude on transformer-based text encoders like BERT? Is it advantageous to use them for similar tasks (over RNN-based models)? If so, where does the advantage come from? [10%]
#
# 3. How could the performance of the biLSTM-based models be improved further? Name all possible steps/ideas you would explore to achieve a higher accuracy on the sentiment classification task. [10%]
#
# 4. Create a plot showing the results (accuracy) of all four models you tested in this notebook: the two BERT-based models and the two biLSTMs. Choose a visualization that allows for a clear and immediate comparison between the various models, as if you were to add it into a scientific paper/report. Don't forget to include the chance level (i.e., the accuracy a random, untrained model would achieve for the task) in the plot. Import all the necessary libraries you may need. [10%]

# %% [markdown]
# **1.** The linear biLSTM achieved a slightly higher validation accuracy (0.635) and higher loss (0.605) compared to the FFNN version (accuracy 0.615, loss 0.593); the FFNN version has more trainable parameters (~1.61M vs ~1.48M) due to the added 512-dimensional projection layer.
#
# **2.** Yes, BERT substantially outperforms the biLSTM (0.785 vs ~0.635 accuracy), because its large-scale pretraining on billions of tokens gives it rich, contextual word representations that transfer effectively to downstream tasks without learning language from scratch.
#
# **3.** Performance could be improved by initialising the embedding layer with pretrained vectors (e.g., GloVe or fastText), training for more epochs with early stopping, stacking multiple LSTM layers, or fine-tuning the entire model end-to-end rather than learning only the top-level classifier.
#
# **4.** See code cell below.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Accuracy values (test set) — replace with your own numbers if you ran the cells
models = [
    "BERT\n(linear)",
    "BERT\n(FFNN)",
    "biLSTM\n(linear)",
    "biLSTM\n(FFNN)",
]
accuracies = [0.785, 0.785, 0.635, 0.615]  # update with actual values after running
chance_level = 0.5  # binary classification

fig, ax = plt.subplots(figsize=(7, 5))
colors = ["#4C72B0", "#4C72B0", "#DD8452", "#DD8452"]
bars = ax.bar(models, accuracies, color=colors, edgecolor="black", width=0.5)

ax.axhline(chance_level, color="red", linestyle="--", linewidth=1.5, label="Chance level (0.50)")

for bar, acc in zip(bars, accuracies):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005,
            f"{acc:.3f}", ha="center", va="bottom", fontsize=10)

ax.set_ylim(0, 1.0)
ax.set_ylabel("Test Accuracy", fontsize=12)
ax.set_title("Sentiment Classification Accuracy\nBERT-based vs. biLSTM models", fontsize=13)
ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Use of AI Tools
#
# By submitting this notebook for grading you testify that:
#
# * AI did not draft an earlier version of your work.
# * You did not use AI-powered code completion.
# * You did not implement algorithms suggested by an AI tool.
# * AI did not revise a version of your work.
# * You did not implement suggestions made by an Al tool.
#
# You in the sentences above refers to you and all your team members. AI refers to LM-based tools and assistants (e.g., ChatGPT, Gemini, UvA AI chat, etc.).
#
# If you did make use of an AI tool, you should describe the uses you made of it below. Or indicate that no such tool was used.

# %% [markdown]
# We did not use any AI tools during this whole assignment
# All code and comments are hand written
